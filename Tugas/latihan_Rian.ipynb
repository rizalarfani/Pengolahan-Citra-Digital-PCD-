# %%
print("Toko Sembako")
Nomor1= str(input("masukan nama barang : "))
Nomor2= int(input("masukan harga barang: "))
Nomor3= int(input("masukan jumlah barang yang dibeli: "))
Nomor4= int(input("jumlah uang yang dibayar: "))
Total= (Nomor2*Nomor3-Nomor4)
print("total kembalian: ","Rp.",Total)
# Out:
# Toko Sembako
# masukan nama barang : minyak goreng
# masukan harga barang: 15000
# masukan jumlah barang yang dibeli: 1
# jumlah uang yang dibayar: 20000
# total kembalian:  Rp. -5000
