# %%
print("Nama : Naufal Akbar Fawaazi")
print("Nim  : 20040067")
print("Prodi: D3 Teknik Komputer")
print("Kelas: 4B")
# Out:
# Nama : Naufal Akbar Fawaazi
# Nim  : 20040067
# Prodi: D3 Teknik Komputer
# Kelas: 4B

# %%
import turtle
t=turtle.Turtle()

t.pensize(5)
t.color("black")
t.begin_fill()
t.fillcolor("red")
t.left(140)
t.forward(180)
t.circle(-90,200)
#left(120)

t.setheading(60)
t.circle(-90,200)
t.forward(180)
t.end_fill()
